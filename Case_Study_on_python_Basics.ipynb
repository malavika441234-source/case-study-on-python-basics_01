# %% [markdown]
# 1. Bank Account Manager
#
# a. Simulate a bank account with deposit, withdrawal, and balance
# enquiry operations
#
# b. Use variables and data types to store account information
#
# c.  Implement conditional statements to check for sufficient balance
# before withdrawal
#
# d. Use functions to perform deposit, withdrawal, and balance inquiry
# operations.

# %%
def withdraw(bal):
  with_amt=float(input('Enter the amount to withdraw: '))
  if bal>with_amt:
    bal=bal-with_amt
    print(with_amt,' ruppees withdrawed')
  else:
    print('Insufficient balance!!!')
  return bal

# %%
def deposit(bal):
  dep_amt=float(input('Enter the amount to deposit: '))
  if dep_amt>10000:
    print('This amount exceeds the one time limit')
  else:
    bal=dep_amt+bal
  return bal

# %%
balance=10000.0
print(' Welcome to ABC bank\n----------------------\nWhat can we do for you today?\n')
print('1. Withdraw cash\n2. Deposit cash\n3. Check Balance\n4. Quit ')
while True:
  option=int(input('Choose your option (1-4): '))
  if option==1:
    balance=withdraw(balance)
  elif option==2:
    balance=deposit(balance)
  elif option==3:
    print('Your current balance is: ',balance)
  elif option==4:
    print('Thank you...')
    break
  else:
    print('Select a valid option')
# Out:
#  Welcome to ABC bank
# ----------------------
# What can we do for you today?
#
# 1. Withdraw cash
# 2. Deposit cash
# 3. Check Balance
# 4. Quit
# Choose your option (1-4): 1
# Enter the amount to withdraw: 5000
# 5000.0  ruppees withdrawed
# Choose your option (1-4): 3
# Your current balance is:  5000.0
# Choose your option (1-4): 2
# Enter the amount to deposit: 8000
# Choose your option (1-4): 4
# Thank you...

# %% [markdown]
# 2. Weather Data Analyzer
#
# a.  Analyze weather data (temperature, humidity, etc.) for a given region
#
# b. Use variables and data types to store weather data
# (sunny, rainy, etc.)
# print results
#
# c. Implement conditional statements to determine weather conditions
#
# d. Use functions to calculate average temperature and humidity, and

# %% [markdown]
# 3. Password Validator
# Write a function that checks if a password is strong: at least 8 characters,
# contains at least one digit, one uppercase letter, and one special character
# (!@#$%).

# %%
password=input('Enter password')
dig=0
upper=0
symb=0
symbol='!@#$%'
if len(password)>=8:
  for i in password:
    if i.isdigit():
      dig=dig+1
    if i.isupper():
      upper=upper+1
    if i in symbol:
      symb=symb+1
  if dig>0 and upper>0 and symb>0:
    print('Strong Password')
  else:
    print('Weak password!')
else:
  print('weak password!!')
# Out:
# Enter passwordAruna@1tg
# Strong Password

# %% [markdown]
# 4. Word Frequency Counter
# Given a paragraph of text, write a function that returns the 3 most
# frequently occurring words (ignore case and punctuation).

# %%
text = "The sun is bright and the sky is blue. The sun shines over the hills and the sun warms the day."
text=text.replace(',',' ')
text=text.replace('.',' ')
text=text.lower()
list_text=text.split(' ')
len(list_text)
for i in range(0,23):
  for j in range(1,23)
  if list_text[i]==list_text[j]
# Out:
# 23

# %%
text
# Out:
# 'the sun is bright and the sky is blue  the sun shines over the hills and the sun warms the day '

# %% [markdown]
# 5. FizzBuzz Variant
#
# Print numbers 1 to 50, but replace multiples of 3 with "Fizz", multiples of 5
# with "Buzz", multiples of both with "FizzBuzz" — and multiples of 7 with
# "Bang".

# %%
for i in range(1,51):
  if i%3==0 and i%5==0:
    print('FizzBuzz')
  elif i%3==0:
    print('Fizz')
  elif i%5==0:
    print('Buzz')
  elif i%7==0:
    print('Bang')
  else:
    print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# Bang
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# Bang
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# Bang
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# Bang
# Buzz
